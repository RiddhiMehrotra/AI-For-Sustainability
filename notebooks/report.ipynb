# %% [markdown]
# From the confusion matrix the model performs best on Cropland class, as it has the strongest true-positive diagonal.
# The model often confuses built-up and vegetation with cropland likely because the textures in Sentinel-2 RGB imagery are visually similar.
# Water has very few samples which causes reduction in acuracy for that class.
# Test accuracy shown is 0.805, it's high because of Cropland class since it is a majority class in our dataset and Test F1-score is 0.395, meaning the model is not performing well on minority classes which reduces balance in F1 performance.
